# %% [markdown]
# <a href="https://colab.research.google.com/github/nosovdmitry007/Neural-Style-Transfer-based-on-CNN/blob/main/Neural_Style_Transfer_based_on_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/zehuac/Neural-Style-Transfer-based-on-CNN.git
# Out:
# Cloning into 'Neural-Style-Transfer-based-on-CNN'...
# remote: Enumerating objects: 538, done.
# remote: Total 538 (delta 0), reused 0 (delta 0), pack-reused 538
# Receiving objects: 100% (538/538), 54.58 MiB | 33.53 MiB/s, done.
# Resolving deltas: 100% (223/223), done.

# %%
# %cd /content/Neural-Style-Transfer-based-on-CNN
# Out:
# /content/Neural-Style-Transfer-based-on-CNN

# %%
import urllib.request

# %%
# !mkdir /content/Neural-Style-Transfer-based-on-CNN/pre_trained_model

# %%
logo = urllib.request.urlopen('http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat').read()
f = open('/content/Neural-Style-Transfer-based-on-CNN/pre_trained_model/imagenet-vgg-verydeep-19.mat', "wb")
f.write(logo)
f.close()

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
#with tf.init_scope():
# !python run_main.py --content /content/img.jpg --style /content/img_style.jpg --output /content/Neural-Style-Transfer-based-on-CNN/result.jpg
# Out:
# WARNING:tensorflow:From run_main.py:158: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From run_main.py:158: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-04-29 18:37:31.005787: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-04-29 18:37:31.006057: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2981100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-04-29 18:37:31.006093: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-04-29 18:37:31.007615: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...
